# %% [markdown]
# <a href="https://colab.research.google.com/github/mehmoodosman/mistral-ocr/blob/main/PDF_OCRmyPDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Convert PDF to OCR Searchable PDF !

# %% [markdown]
# You can reduce the lib imports section (but don't forget to run it).

# %% [markdown]
# ## Lib imports

# %% [markdown]
# Main OCR Lib can be found here : https://github.com/jbarlow83/OCRmyPDF
# Everything else is a compulsory dependency.

# %%
! apt install tesseract-ocr
! apt install libtesseract-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libarchive-dev libleptonica-dev
# The following NEW packages will be installed:
#   libarchive-dev libleptonica-dev libtesseract-dev
# 0 upgraded, 3 newly installed, 0 to remove and 34 not upgraded.
# Need to get 3,743 kB of archives.
# After this operation, 16.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libarchive-dev amd64 3.6.0-1ubuntu1.4 [581 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libleptonica-dev amd64 1.82.0-3build1 [1,562 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtesseract-dev amd64 4.1.1-2.1build1 [1,600 kB]
# Fetched 3,743 kB in 1s (3,358 kB/s)
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 126101 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.6.0-1ubuntu1.4_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.6.0-1ubuntu1.4) ...
# Selecting previously unselected package libleptonica-dev.
# Preparing to unpack .../libleptonica-dev_1.82.0-3build1_amd64.deb ...
# Unpacking libleptonica-dev (1.82.0-3build1) ...
# Selecting previously unselected package libtesseract-dev:amd64.
# Preparing to unpack .../libtesseract-dev_4.1.1-2.1build1_amd64.deb ...
# Unpacking libtesseract-dev:amd64 (4.1.1-2.1build1) ...
# Setting up libleptonica-dev (1.82.0-3build1) ...
# Setting up libarchive-dev:amd64 (3.6.0-1ubuntu1.4) ...
# Setting up libtesseract-dev:amd64 (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (11.2.1)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
# !apt install ghostscript
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 libgs9 libgs9-common
#   libidn12 libijs-0.35 libjbig2dec0 poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   ghostscript-x poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript libgs9
#   libgs9-common libidn12 libijs-0.35 libjbig2dec0 poppler-data
# 0 upgraded, 10 newly installed, 0 to remove and 34 not upgraded.
# Need to get 16.7 MB of archives.
# After this operation, 63.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.11 [753 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.11 [5,031 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.11 [49.4 kB]
# Fetched 16.7 MB in 3s (6,069 kB/s)
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 126234 files and directories currently installed.)
# Preparing to unpack .../0-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../1-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../2-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../3-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../4-libgs9-common_9.55.0~dfsg1-0ubuntu5.11_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.11) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../5-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../6-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../7-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../8-libgs9_9.55.0~dfsg1-0ubuntu5.11_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.11) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../9-ghostscript_9.55.0~dfsg1-0ubuntu5.11_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.11) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.11) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.11) ...
# Setting up ghostscript (9.55.0~dfsg1-0ubuntu5.11) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install ocrmypdf
# Out:
# Collecting ocrmypdf
#   Downloading ocrmypdf-16.10.1-py3-none-any.whl.metadata (11 kB)
# Collecting deprecation>=2.1.0 (from ocrmypdf)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting img2pdf>=0.5 (from ocrmypdf)
#   Downloading img2pdf-0.6.1.tar.gz (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from ocrmypdf) (24.2)
# Collecting pdfminer-six>=20220319 (from ocrmypdf)
#   Downloading pdfminer_six-20250416-py3-none-any.whl.metadata (4.1 kB)
# Collecting pi-heif (from ocrmypdf)
#   Downloading pi_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting pikepdf>=8.10.1 (from ocrmypdf)
#   Downloading pikepdf-9.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: pillow>=10.0.1 in /usr/local/lib/python3.11/dist-packages (from ocrmypdf) (11.2.1)
# Requirement already satisfied: pluggy>=1 in /usr/local/lib/python3.11/dist-packages (from ocrmypdf) (1.5.0)
# Requirement already satisfied: rich>=13 in /usr/local/lib/python3.11/dist-packages (from ocrmypdf) (13.9.4)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer-six>=20220319->ocrmypdf) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer-six>=20220319->ocrmypdf) (43.0.3)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from pikepdf>=8.10.1->ocrmypdf) (1.2.18)
# Requirement already satisfied: lxml>=4.8 in /usr/local/lib/python3.11/dist-packages (from pikepdf>=8.10.1->ocrmypdf) (5.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13->ocrmypdf) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13->ocrmypdf) (2.19.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (1.17.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13->ocrmypdf) (0.1.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->pikepdf>=8.10.1->ocrmypdf) (1.17.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (2.22)
# Downloading ocrmypdf-16.10.1-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.4/162.4 kB 9.8 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading pdfminer_six-20250416-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 61.0 MB/s eta 0:00:00
# Downloading pikepdf-9.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 49.1 MB/s eta 0:00:00
# Downloading pi_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.8 MB/s eta 0:00:00
# Building wheels for collected packages: img2pdf
#   Building wheel for img2pdf (setup.py) ... done
#   Created wheel for img2pdf: filename=img2pdf-0.6.1-py3-none-any.whl size=51001 sha256=0b33cc60e455026c3c1403739ccd67e3725ca2d22304795fbfcb8fa918b938b8
#   Stored in directory: /root/.cache/pip/wheels/21/0a/64/6a8143672bcea0d35b8cf705ba12b11bb191367cfde88d4f35
# Successfully built img2pdf
# Installing collected packages: pi-heif, deprecation, pikepdf, pdfminer-six, img2pdf, ocrmypdf
# Successfully installed deprecation-2.1.0 img2pdf-0.6.1 ocrmypdf-16.10.1 pdfminer-six-20250416 pi-heif-0.22.0 pikepdf-9.7.0

# %%
# !ocrmypdf --help
# Out:
# usage: OCRmyPDF [-h] [-l LANGUAGES] [--image-dpi DPI]
#                 [--output-type {pdfa,pdf,pdfa-1,pdfa-2,pdfa-3,none}]
#                 [--sidecar [FILE]] [--version] [-j N] [-q] [-v [VERBOSE]]
#                 [--title TITLE] [--author AUTHOR] [--subject SUBJECT]
#                 [--keywords KEYWORDS] [-r] [--remove-background] [-d] [-c]
#                 [-i] [--unpaper-args UNPAPER_ARGS] [--oversample DPI]
#                 [--remove-vectors] [-f] [-s] [--redo-ocr] [--skip-big MPixels]
#                 [--invalidate-digital-signatures] [--pages PAGES]
#                 [--max-image-mpixels MPixels]
#                 [--pdf-renderer {auto,hocr,sandwich,hocrdebug}]
#                 [--rotate-pages-threshold CONFIDENCE]
#                 [--fast-web-view MEGABYTES] [--continue-on-soft-render-error]
#                 [--plugin PLUGINS] [-k] [--tesseract-config CFG]
#                 [--tesseract-pagesegmode PSM] [--tesseract-oem MODE]
#                 [--tesseract-thresholding METHOD]
#                 [--tesseract-timeout SECONDS]
#                 [--tesseract-non-ocr-timeout SECONDS]
#                 [--tesseract-downsample-large-images | --no-tesseract-downsample-large-images]
#                 [--tesseract-downsample-above TESSERACT_DOWNSAMPLE_ABOVE]
#                 [--user-words FILE] [--user-patterns FILE] [-O {0,1,2,3}]
#                 [--jpeg-quality Q] [--png-quality Q] [--jbig2-lossy]
#                 [--jbig2-threshold T] [--color-conversion-strategy STRATEGY]
#                 [--pdfa-image-compression {auto,jpeg,lossless}]
#                 input_pdf_or_image output_pdf
#
# Generates a searchable PDF or PDF/A from a regular PDF.
#
# OCRmyPDF rasterizes each page of the input PDF, optionally corrects page
# rotation and performs image processing, runs the Tesseract OCR engine on the
# image, and then creates a PDF from the OCR information.
#
# positional arguments:
#   input_pdf_or_image    PDF file containing the images to be OCRed (or '-' to
#                         read from standard input)
#   output_pdf            Output searchable PDF file (or '-' to write to
#                         standard output). Existing files will be overwritten.
#                         If same as input file, the input file will be updated
#                         only if processing is successful.
#
# options:
#   -h, --help            show this help message and exit
#   -l LANGUAGES, --language LANGUAGES
#                         Language(s) of the file to be OCRed (see tesseract
#                         --list-langs for all language packs installed in your
#                         system). Use -l eng+deu for multiple languages.
#   --image-dpi DPI       When the input file is an image, not a PDF, use this
#                         DPI instead of the DPI claimed by the input file. If
#                         the input does not claim a sensible DPI, this option
#                         will be required.
#   --output-type {pdfa,pdf,pdfa-1,pdfa-2,pdfa-3,none}
#                         Choose output type. 'pdfa' creates a PDF/A-2b
#                         compliant file for long term archiving (default,
#                         recommended) but may not suitable for users who want
#                         their file altered as little as possible. 'pdfa' also
#                         has problems with full Unicode text. 'pdf' minimizes
#                         changes to the input file. 'pdf-a1' creates a PDF/A1-b
#                         file. 'pdf-a2' is equivalent to 'pdfa'. 'pdf-a3'
#                         creates a PDF/A3-b file. 'none' will produce no
#                         output, which may be helpful if only the --sidecar is
#                         desired.
#   --sidecar [FILE]      Generate sidecar text files that contain the same text
#                         recognized by Tesseract. This may be useful for
#                         building a OCR text database. If FILE is omitted, the
#                         sidecar file be named {output_file}.txt; the next
#                         argument must NOT be the name of the input PDF. If
#                         FILE is set to '-', the sidecar is written to stdout
#                         (a convenient way to preview OCR quality). The output
#                         file and sidecar may not both use stdout at the same
#                         time.
#   --version             Print program version and exit
#
# Job control options:
#   -j N, --jobs N        Use up to N CPU cores simultaneously (default: use
#                         all).
#   -q, --quiet           Suppress INFO messages
#   -v [VERBOSE], --verbose [VERBOSE]
#                         Print more verbose messages for each additional
#                         verbose level. Use `-v 1` typically for much more
#                         detailed logging. Higher numbers are probably only
#                         useful in debugging.
#
# Metadata options:
#   Set output PDF/A metadata (default: copy input document's metadata)
#
#   --title TITLE         Set document title (place multiple words in quotes)
#   --author AUTHOR       Set document author
#   --subject SUBJECT     Set document subject description
#   --keywords KEYWORDS   Set document keywords
#
# Image preprocessing options:
#   Options to improve the quality of the final PDF and OCR
#
#   -r, --rotate-pages    Automatically rotate pages based on detected text
#                         orientation
#   --remove-background   Attempt to remove background from gray or color pages,
#                         setting it to white
#   -d, --deskew          Deskew each page before performing OCR
#   -c, --clean           Clean pages from scanning artifacts before performing
#                         OCR, and send the cleaned page to OCR, but do not
#                         include the cleaned page in the output
#   -i, --clean-final     Clean page as above, and incorporate the cleaned image
#                         in the final PDF. Might remove desired content.
#   --unpaper-args UNPAPER_ARGS
#                         A quoted string of arguments to pass to unpaper.
#                         Requires --clean. Example: --unpaper-args '--layout
#                         double'.
#   --oversample DPI      Oversample images to at least the specified DPI, to
#                         improve OCR results slightly
#   --remove-vectors      EXPERIMENTAL. Mask out any vector objects in the PDF
#                         so that they will not be included in OCR. This can
#                         eliminate false characters.
#
# OCR options:
#   Control how OCR is applied
#
#   -f, --force-ocr       Rasterize any text or vector objects on each page,
#                         apply OCR, and save the rastered output (this rewrites
#                         the PDF)
#   -s, --skip-text       Skip OCR on any pages that already contain text, but
#                         include the page in final output; useful for PDFs that
#                         contain a mix of images, text pages, and/or previously
#                         OCRed pages
#   --redo-ocr            Attempt to detect and remove the hidden OCR layer from
#                         files that were previously OCRed with OCRmyPDF or
#                         another program. Apply OCR to text found in raster
#                         images. Existing visible text objects will not be
#                         changed. If there is no existing OCR, OCR will be
#                         added.
#   --skip-big MPixels    Skip OCR on pages larger than the specified amount of
#                         megapixels, but include skipped pages in final output
#   --invalidate-digital-signatures
#                         Normally, OCRmyPDF will refuse to OCR a PDF that has a
#                         digital signature. This option allows OCR to proceed,
#                         but the digital signature will be invalidated.
#
# Advanced:
#   Advanced options to control OCRmyPDF
#
#   --pages PAGES         Limit OCR to the specified pages (ranges or comma
#                         separated), skipping others
#   --max-image-mpixels MPixels
#                         Set maximum number of megapixels to unpack before
#                         treating an image as a decompression bomb
#   --pdf-renderer {auto,hocr,sandwich,hocrdebug}
#                         Choose OCR PDF renderer - the default option is to let
#                         OCRmyPDF choose. See documentation for discussion.
#   --rotate-pages-threshold CONFIDENCE
#                         Only rotate pages when confidence is above this value
#                         (arbitrary units reported by tesseract)
#   --fast-web-view MEGABYTES
#                         If the size of file is more than this threshold (in
#                         MB), then linearize the PDF for fast web viewing. This
#                         allows the PDF to be displayed before it is fully
#                         downloaded in web browsers, but increases the space
#                         required slightly. By default we skip this for small
#                         files which do not benefit. If the threshold is 0 it
#                         will be apply to all files. Set the threshold very
#                         high to disable.
#   --continue-on-soft-render-error
#                         Continue processing pages after a recoverable PDF
#                         rendering error. A recoverable error is one that does
#                         not prevent the page from being rendered, but may
#                         result in visual differences compared to the input
#                         file. Missing fonts are a typical source of these
#                         errors.
#   --plugin PLUGINS      Name of plugin to import. Argument may be issued
#                         multiple times to import multiple plugins. Plugins may
#                         be specified as module names in Python syntax,
#                         provided they are installed in the same Python
#                         (virtual) environment as ocrmypdf; or you may give the
#                         path to the Python file that contains the plugin.
#                         Plugins must conform to the specification in the
#                         OCRmyPDF documentation.
#
# Debugging:
#   Arguments to help with troubleshooting and debugging
#
#   -k, --keep-temporary-files
#                         Keep temporary files (helpful for debugging)
#
# Tesseract:
#   Advanced control of Tesseract OCR
#
#   --tesseract-config CFG
#                         Additional Tesseract configuration files -- see
#                         documentation.
#   --tesseract-pagesegmode PSM
#                         Set Tesseract page segmentation mode (see tesseract
#                         --help).
#   --tesseract-oem MODE  Set Tesseract 4+ OCR engine mode: 0 - original
#                         Tesseract only; 1 - neural nets LSTM only; 2 -
#                         Tesseract + LSTM; 3 - default.
#   --tesseract-thresholding METHOD
#                         Set Tesseract 5.0+ input image thresholding mode. This
#                         may improve OCR results on low quality images or those
#                         that contain high contrast color. legacy-otsu is the
#                         Tesseract default; adaptive-otsu is an improved Otsu
#                         algorithm with improved sort for background color
#                         changes; sauvola is based on local standard deviation.
#   --tesseract-timeout SECONDS
#                         Give up on OCR after the timeout, but copy the
#                         preprocessed page into the final output. This timeout
#                         is only used when using Tesseract for OCR. When
#                         Tesseract is used for other operations such as
#                         deskewing and orientation, the timeout is controlled
#                         by --tesseract-non-ocr-timeout.
#   --tesseract-non-ocr-timeout SECONDS
#                         Give up on non-OCR operations such as deskewing and
#                         orientation after timeout. This is a separate timeout
#                         from --tesseract-timeout because these operations are
#                         not as expensive as OCR.
#   --tesseract-downsample-large-images, --no-tesseract-downsample-large-images
#                         Downsample large images before OCR. Tesseract has an
#                         upper limit on the size images it will support. If
#                         this argument is given, OCRmyPDF will downsample large
#                         images to fit Tesseract. This may reduce OCR quality,
#                         on large images the most desirable text is usually
#                         larger. If this parameter is not supplied, Tesseract
#                         will error out and produce no OCR on the page in
#                         question. This argument should be used with a high
#                         value of --tesseract-timeout to ensure Tesseract has
#                         enough to time.
#   --tesseract-downsample-above TESSERACT_DOWNSAMPLE_ABOVE
#                         Downsample images larger than this size pixel size in
#                         either dimension before OCR. --tesseract-downsample-
#                         large-images downsamples only when an image exceeds
#                         Tesseract's internal limits. This argument causes
#                         downsampling to occur when an image exceeds the given
#                         size. This may reduce OCR quality, but on large images
#                         the most desirable text is usually larger.
#   --user-words FILE     Specify the location of the Tesseract user words file.
#                         This is a list of words Tesseract should consider
#                         while performing OCR in addition to its standard
#                         language dictionaries. This can improve OCR quality
#                         especially for specialized and technical documents.
#   --user-patterns FILE  Specify the location of the Tesseract user patterns
#                         file.
#
# Optimization options:
#   Control how the PDF is optimized after OCR
#
#   -O {0,1,2,3}, --optimize {0,1,2,3}
#                         Control how PDF is optimized after processing:0 - do
#                         not optimize; 1 - do safe, lossless optimizations
#                         (default); 2 - do lossy JPEG and JPEG2000
#                         optimizations; 3 - do more aggressive lossy JPEG and
#                         JPEG2000 optimizations. To enable lossy JBIG2, see
#                         --jbig2-lossy.
#   --jpeg-quality Q      Adjust JPEG quality level for JPEG optimization. 100
#                         is best quality and largest output size; 1 is lowest
#                         quality and smallest output; 0 uses the default.
#   --png-quality Q       Adjust PNG quality level to use when quantizing PNGs.
#                         Values have same meaning as with --jpeg-quality
#   --jbig2-lossy         Enable JBIG2 lossy mode (better compression, not
#                         suitable for some use cases - see documentation). Only
#                         takes effect if --optimize 1 or higher is also
#                         enabled.
#   --jbig2-threshold T   Adjust JBIG2 symbol code classification threshold
#                         (default 0.85), range 0.4 to 0.9.
#
# Ghostscript:
#   Advanced control of Ghostscript
#
#   --color-conversion-strategy STRATEGY
#                         Set Ghostscript color conversion strategy
#   --pdfa-image-compression {auto,jpeg,lossless}
#                         Specify how to compress images in the output PDF/A.
#                         'auto' lets OCRmyPDF decide. 'jpeg' changes all
#                         grayscale and color images to JPEG compression.
#                         'lossless' uses PNG-style lossless compression for all
#                         images. Monochrome images are always compressed using
#                         a lossless codec. Compression settings are applied to
#                         all pages, including those for which OCR was skipped.
#                         Not supported for --output-type=pdf ; that setting
#                         preserves the original compression of all images.
#
# OCRmyPDF attempts to keep the output file at about the same size.  If a file
# contains losslessly compressed images, and images in the output file will be
# losslessly compressed as well.
#
# PDF is a page description file that attempts to preserve a layout exactly.
# A PDF can contain vector objects (such as text or lines) and raster objects
# (images).  A page might have multiple images.  OCRmyPDF is prepared to deal
# with the wide variety of PDFs that exist in the wild.
#
# When a PDF page contains text, OCRmyPDF assumes that the page has already
# been OCRed or is a "born digital" page that should not be OCRed.  The default
# behavior is to exit in this case without producing a file.  You can use the
# option --skip-text to ignore pages with text, or --force-ocr to rasterize
# all objects on the page and produce an image-only PDF as output.
#
#     ocrmypdf --skip-text file_with_some_text_pages.pdf output.pdf
#
#     ocrmypdf --force-ocr word_document.pdf output.pdf
#
# If you are concerned about long-term archiving of PDFs, use the default option
# --output-type pdfa which converts the PDF to a standardized PDF/A-2b.  This
# removes some features from the PDF such as Javascript or forms. If you want to
# minimize the number of changes made to your PDF, use --output-type pdf.
#
# If OCRmyPDF is given an image file as input, it will attempt to convert the
# image to a PDF before processing.  For more control over the conversion of
# images to PDF, use the Python package img2pdf or other image to PDF software.
#
# For example, this command uses img2pdf to convert all .png files beginning
# with the 'page' prefix to a PDF, fitting each image on A4-sized paper, and
# sending the result to OCRmyPDF through a pipe.
#
#     img2pdf --pagesize A4 page*.png | ocrmypdf - myfile.pdf
#
# Online documentation is located at:
#     https://ocrmypdf.readthedocs.io/en/latest/introduction.html

# %%
from ctypes.util import find_library
find_library("gs")
# Out:
# 'libgs.so.9'

# %%
#optional imports to make a pretty list
import pandas as pd
# %load_ext google.colab.data_table

# %%
# !mkdir input_papers
# !mkdir output_papers

# %% [markdown]
# ## OCR Execution

# %% [markdown]
# <==== click on the Folder logo.
# Drag and drop you files in the "input_papers" folder.
# The output files will be located in the "output_papers" folder.
# (If the folders are not visible, refresh the explorer with the refresh button)

# %%
import os
file_list = []

input_folder_path = "/content/input_papers"
output_folder_path = "/content/output_papers"

for filename in os.listdir(input_folder_path):
    if filename.endswith("pdf"):
      file_list.append(filename)

print("The following files will be converted : ")
pd.DataFrame(file_list, columns=["Filename"])
# Out:
# The following files will be converted :
#           Filename
# 0  Saima_pac_2.pdf
# 1  Saima_pac_4.pdf

# %% [markdown]
# Warning : several minutes per file, please check the above list before proceeding.

# %%
for filename in file_list:
  print("Converting : " + filename)
  input_filename = input_folder_path+'/'+filename
  output_filename = output_folder_path+'/'+filename
  # !ocrmypdf --force-ocr "{input_filename}" "{output_filename}"
# Out:
# Converting : Saima_pac_2.pdf
# Scanning contents     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 58/58 0:00:00
# Start processing 2 pages concurrently                                  ]8;id=5552;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/ocr.py\ocr.py]8;;\:]8;id=362819;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/ocr.py#96\96]8;;\
#     2 page already has text! - rasterizing text and running OCR ]8;id=67475;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=141987;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#     2 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=236873;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=678135;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#     2 [tesseract] Image too small to scale!! (2x36 vs min width ]8;id=876144;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=761668;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#259\259]8;;\
# of 3)
#     2 [tesseract] Line cannot be recognized!!                   ]8;id=79616;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=915369;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#259\259]8;;\
#     3 page already has text! - rasterizing text and running OCR ]8;id=176277;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=449040;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#     1 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=591723;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=949115;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#     4 page already has text! - rasterizing text and running OCR ]8;id=444351;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=516383;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#     6 page already has text! - rasterizing text and running OCR ]8;id=468082;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=743314;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#     7 page already has text! - rasterizing text and running OCR ]8;id=406347;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=401749;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    15 page already has text! - rasterizing text and running OCR ]8;id=610376;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=225345;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    16 page already has text! - rasterizing text and running OCR ]8;id=380810;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=185878;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    21 page already has text! - rasterizing text and running OCR ]8;id=661498;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=536705;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    22 page already has text! - rasterizing text and running OCR ]8;id=680528;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=692282;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    27 page already has text! - rasterizing text and running OCR ]8;id=116942;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=697559;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    28 page already has text! - rasterizing text and running OCR ]8;id=905270;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=186183;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    29 page already has text! - rasterizing text and running OCR ]8;id=835905;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=64091;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    30 page already has text! - rasterizing text and running OCR ]8;id=439011;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=311598;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    31 page already has text! - rasterizing text and running OCR ]8;id=554906;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=662602;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    32 page already has text! - rasterizing text and running OCR ]8;id=504862;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=17988;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    29 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=11098;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=562722;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    33 page already has text! - rasterizing text and running OCR ]8;id=798969;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=610773;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    34 page already has text! - rasterizing text and running OCR ]8;id=197812;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=231090;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    32 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=507477;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=208013;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    35 page already has text! - rasterizing text and running OCR ]8;id=991608;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=353421;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    36 page already has text! - rasterizing text and running OCR ]8;id=715960;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=19771;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    37 page already has text! - rasterizing text and running OCR ]8;id=650162;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=480568;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    38 page already has text! - rasterizing text and running OCR ]8;id=369467;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=492465;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    39 page already has text! - rasterizing text and running OCR ]8;id=100878;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=755708;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    40 page already has text! - rasterizing text and running OCR ]8;id=539203;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=235420;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    36 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=571428;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=970248;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    41 page already has text! - rasterizing text and running OCR ]8;id=781555;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=869143;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    42 page already has text! - rasterizing text and running OCR ]8;id=813011;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=703636;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    43 page already has text! - rasterizing text and running OCR ]8;id=624404;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=333634;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    40 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=976342;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=620583;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    44 page already has text! - rasterizing text and running OCR ]8;id=387152;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=316336;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    45 page already has text! - rasterizing text and running OCR ]8;id=788666;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=718998;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
#    43 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=507025;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=553843;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    46 page already has text! - rasterizing text and running OCR ]8;id=123752;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=407360;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#331\331]8;;\
# anyway
# OCR                   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 58/58 0:00:00
# Postprocessing...                                                     ]8;id=561963;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/ocr.py\ocr.py]8;;\:]8;id=130749;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/ocr.py#144\144]8;;\
# PDF/A conversion      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 58/58 0:00:00
# Linearizing           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 100/100 0:00:00
# Recompressing JPEGs   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:--
# Deflating JPEGs       ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 1/1 0:00:00
# JBIG2                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:--
# Image optimization ratio: 1.00 savings: 0.0%                   ]8;id=828208;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=253634;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#1002\1002]8;;\
# Total file size ratio: 0.91 savings: -10.4%                    ]8;id=838592;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=313868;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#1005\1005]8;;\
# Output file is a PDF/A-2B (as expected)                           ]8;id=952042;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/_common.py\_common.py]8;;\:]8;id=618993;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/_common.py#474\474]8;;\
# Converting : Saima_pac_4.pdf
# Scanning contents     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 136/136 0:00:00
# Start processing 2 pages concurrently                                  ]8;id=89725;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/ocr.py\ocr.py]8;;\:]8;id=988623;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/ocr.py#96\96]8;;\
#     1 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=388470;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=645863;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#     2 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=889946;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=592829;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#     4 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=589873;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=991518;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#     3 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=54738;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=811255;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#     5 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=398018;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=943484;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#     6 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=398365;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=210605;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#     8 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=185502;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=122849;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    10 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=587627;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=789256;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    13 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=507463;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=662016;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    15 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=278262;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=805824;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    17 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=463022;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=538060;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    19 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=432149;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=15090;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    23 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=767935;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=209072;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    22 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=853574;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=435749;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    24 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=710136;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=387050;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    29 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=890987;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=114018;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    30 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=679474;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=521195;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    35 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=899209;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=621354;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    38 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=427404;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=688358;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    37 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=570990;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=780520;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    39 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=396183;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=707422;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    40 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=490131;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=164987;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    41 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=62674;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=614759;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    43 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=287313;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=313380;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    44 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=273562;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=515621;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    50 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=160195;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=37952;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    49 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=296068;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=544444;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    51 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=677385;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=460892;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    52 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=787819;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=706248;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    53 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=613648;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=677316;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    55 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=472709;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=401449;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    54 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=395506;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=619024;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    57 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=420514;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=551137;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    56 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=345660;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=665813;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    58 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=199294;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=474179;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    59 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=527696;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=233572;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    60 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=471723;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=659750;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    61 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=306794;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=221798;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    62 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=697322;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=708400;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    66 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=753799;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=187129;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    67 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=776686;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=381331;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    68 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=951464;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=163816;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    69 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=188105;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=753761;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    71 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=428382;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=634139;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    73 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=42218;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=591637;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    74 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=639339;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=790745;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    75 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=411495;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=739548;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    82 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=523821;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=931836;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    84 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=871165;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=586460;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    83 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=475285;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=352410;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    86 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=179836;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=632121;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    85 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=88624;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=632152;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    88 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=240051;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=930253;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    89 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=899978;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=444318;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    90 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=880216;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=486610;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    92 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=751853;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=404821;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    91 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=749360;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=884431;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    94 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=669270;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=964788;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    96 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=625501;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=401187;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    95 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=137138;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=270553;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#    97 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=469995;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=245129;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   100 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=345036;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=683392;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   102 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=902020;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=323700;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   105 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=310665;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=68917;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   106 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=478629;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=256889;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   107 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=377607;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=822754;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   108 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=375232;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=845987;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   114 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=718445;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=872581;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   115 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=149856;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=744849;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   116 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=210542;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=310455;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   117 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=34909;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=368134;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   118 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=54232;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=346369;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   122 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=285172;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=717741;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   121 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=767644;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=779234;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   123 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=654510;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=771749;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   125 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=782231;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=685084;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   129 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=416674;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=406951;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
#   136 [tesseract] lots of diacritics - possibly poor OCR        ]8;id=957261;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py\tesseract.py]8;;\:]8;id=485958;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_exec/tesseract.py#241\241]8;;\
# OCR                   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 136/136 0:00:00
# Postprocessing...                                                     ]8;id=701957;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/ocr.py\ocr.py]8;;\:]8;id=631109;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/ocr.py#144\144]8;;\
# PDF/A conversion      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 136/136 0:00:00
# Linearizing           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 100/100 0:00:00
# Recompressing JPEGs   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:--
# Deflating JPEGs       ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:--
# JBIG2                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:--
# Image optimization did not improve the file - optimizations will ]8;id=304449;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/optimize.py\optimize.py]8;;\:]8;id=198978;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/optimize.py#728\728]8;;\
# not be used
# Image optimization ratio: 1.00 savings: -0.2%                  ]8;id=957403;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=240901;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#1002\1002]8;;\
# Total file size ratio: 0.91 savings: -9.7%                     ]8;id=876278;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py\_pipeline.py]8;;\:]8;id=962654;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipeline.py#1005\1005]8;;\
# Output file is a PDF/A-2B (as expected)                           ]8;id=233168;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/_common.py\_common.py]8;;\:]8;id=552069;file:///usr/local/lib/python3.11/dist-packages/ocrmypdf/_pipelines/_common.py#474\474]8;;\
